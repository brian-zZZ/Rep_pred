# %% [markdown]
# # 构建模型&预测

# %%
import pandas as pd

# 加载已经完成特征工程的训练集和测试集
# 特征工程见feature_engineering.ipynb
split_train_data_feature = pd.read_csv("/home/brian/Projects/Repurchase/trainset_final.csv")
split_test_data_feature = pd.read_csv("/home/brian/Projects/Repurchase/testset_final.csv")
split_test_data = pd.read_csv('/home/brian/Projects/Repurchase/data_format1/test_format1.csv')

# %% [markdown]
# ## 一、调参确定最佳参数

# %% [markdown]
# Note：调参时将加载的训练集拆分为train, validation两部分。而当确定参数后将完整训练集用来训练已获得更强的拟合能力，具体见二。

# %%
import numpy as np
from sklearn.model_selection import train_test_split

# 准备训练集与测试集
label = split_train_data_feature['label']
data = split_train_data_feature.drop(columns=['user_id','merchant_id','label'],axis=1)

# 训练集和测试集切分,确保生成随机数种子，并且训练和测试的样本分配尽量均衡
train_data, validation_data, train_label, validation_label = train_test_split(data,label, test_size = 0.2,random_state = 10)
print(train_data.shape)
print(train_label.shape)
print(validation_data.shape)
print(validation_label.shape)
# 观察训练和测试集的两个数据分布是否均等
print(np.sum(train_label==1)/len(train_label))
print(np.sum((validation_label)==1)/len(validation_label))
# Out:
# (221452, 72)
# (221452,)
# (55364, 72)
# (55364,)
# 0.1148330112168777
# 0.11693519254389134

# %%
# 构建模型并训练，根据验证集指标调参
"""
参数意义：
min_child_weight：子节点的权重阈值。它刻画的是：对于一个叶子节点，当对它采取划分之后，它的所有子节点的权重之和的阈值。值越大算法越保守。
gamma： 也称作最小划分损失min_split_loss。 它刻画的是：对于一个叶子节点，当对它采取划分之后，损失函数的降低值的阈值。值越大算法越保守。
subsample： 对训练样本的采样比例。取值范围为 (0,1]。小的值有助于缓解过拟合。
colsample_bytree： 构建子树时，对特征的采样比例。取值范围为 (0,1]。小的值有助于缓解过拟合。
reg_lambda： L2 正则化系数（基于weights的正则化），默认为 1。 该值越大则模型越简单。
reg_alpha： L1 正则化系数（基于weights的正则化），默认为 0。 该值越大则模型越简单。
scale_pos_weight：=负样本/正样本，正负样本偏差较大时调整该值，使得预测label为正(=1)数量接近真实情况。
"""
import xgboost as xgb

# XGBOOST算法做分类器
xgb_predict_model = xgb.XGBClassifier(
    eta = 0.1,
    n_estimators = 200,
    max_depth = 5, # default=6
    min_child_weight = 300, # default=1
    gamma = 10.3, # default=0
    subsample = 0.8, # default=1
    colsample_bytree = 0.75, # default=1
    reg_alpha = 1.2,
    reg_lambda = 8.16,
    eval_metric = 'auc',
    scale_pos_weight = 4.5
)
xgb_predict_model.fit(
    train_data, 
    train_label, 
    eval_set=[(train_data, train_label),(validation_data, validation_label)],
    verbose = True,
    early_stopping_rounds = 40,
)
# Out:
# /home/brian/anaconda3/lib/python3.8/site-packages/xgboost/sklearn.py:1146: UserWarning: The use of label encoder in XGBClassifier is deprecated and will be removed in a future release. To remove this warning, do the following: 1) Pass option use_label_encoder=False when constructing XGBClassifier object; and 2) Encode your labels (y) as integers starting with 0, i.e. 0, 1, 2, ..., [num_class - 1].
#   warnings.warn(label_encoder_deprecation_msg, UserWarning)
# [0]	validation_0-auc:0.63932	validation_1-auc:0.63031
# [1]	validation_0-auc:0.64923	validation_1-auc:0.63960
# [2]	validation_0-auc:0.65980	validation_1-auc:0.64868
# [3]	validation_0-auc:0.66377	validation_1-auc:0.65092
# [4]	validation_0-auc:0.66600	validation_1-auc:0.65274
# [5]	validation_0-auc:0.66713	validation_1-auc:0.65331
# [6]	validation_0-auc:0.66774	validation_1-auc:0.65409
# [7]	validation_0-auc:0.66887	validation_1-auc:0.65440
# [8]	validation_0-auc:0.66950	validation_1-auc:0.65498
# [9]	validation_0-auc:0.67192	validation_1-auc:0.65675
# [10]	validation_0-auc:0.67311	validation_1-auc:0.65787
# [11]	validation_0-auc:0.67439	validation_1-auc:0.65891
# [12]	validation_0-auc:0.67569	validation_1-auc:0.66006
# [13]	validation_0-auc:0.67746	validation_1-auc:0.66172
# [14]	validation_0-auc:0.67821	validation_1-auc:0.66250
# [15]	validation_0-auc:0.67968	validation_1-auc:0.66365
# [16]	validation_0-auc:0.68033	validation_1-auc:0.66393
# [17]	validation_0-auc:0.68197	validation_1-auc:0.66524
# [18]	validation_0-auc:0.68289	validation_1-auc:0.66571
# [19]	validation_0-auc:0.68453	validation_1-auc:0.66710
# [20]	validation_0-auc:0.68522	validation_1-auc:0.66763
# [21]	validation_0-auc:0.68589	validation_1-auc:0.66823
# [22]	validation_0-auc:0.68654	validation_1-auc:0.66870
# [23]	validation_0-auc:0.68741	validation_1-auc:0.66931
# [24]	validation_0-auc:0.68830	validation_1-auc:0.67029
# [25]	validation_0-auc:0.68904	validation_1-auc:0.67098
# [26]	validation_0-auc:0.68984	validation_1-auc:0.67152
# [27]	validation_0-auc:0.69100	validation_1-auc:0.67231
# [28]	validation_0-auc:0.69156	validation_1-auc:0.67254
# [29]	validation_0-auc:0.69255	validation_1-auc:0.67319
# [30]	validation_0-auc:0.69300	validation_1-auc:0.67352
# [31]	validation_0-auc:0.69424	validation_1-auc:0.67426
# [32]	validation_0-auc:0.69476	validation_1-auc:0.67436
# [33]	validation_0-auc:0.69535	validation_1-auc:0.67472
# [34]	validation_0-auc:0.69566	validation_1-auc:0.67499
# [35]	validation_0-auc:0.69622	validation_1-auc:0.67531
# [36]	validation_0-auc:0.69674	validation_1-auc:0.67558
# [37]	validation_0-auc:0.69745	validation_1-auc:0.67618
# [38]	validation_0-auc:0.69803	validation_1-auc:0.67673
# [39]	validation_0-auc:0.69838	validation_1-auc:0.67702
# [40]	validation_0-auc:0.69910	validation_1-auc:0.67746
# [41]	validation_0-auc:0.69973	validation_1-auc:0.67785
# [42]	validation_0-auc:0.70044	validation_1-auc:0.67829
# [43]	validation_0-auc:0.70115	validation_1-auc:0.67847
# [44]	validation_0-auc:0.70140	validation_1-auc:0.67864
# [45]	validation_0-auc:0.70200	validation_1-auc:0.67927
# [46]	validation_0-auc:0.70250	validation_1-auc:0.67974
# [47]	validation_0-auc:0.70300	validation_1-auc:0.67995
# [48]	validation_0-auc:0.70334	validation_1-auc:0.68032
# [49]	validation_0-auc:0.70418	validation_1-auc:0.68088
# [50]	validation_0-auc:0.70457	validation_1-auc:0.68111
# [51]	validation_0-auc:0.70476	validation_1-auc:0.68139
# [52]	validation_0-auc:0.70530	validation_1-auc:0.68167
# [53]	validation_0-auc:0.70582	validation_1-auc:0.68197
# [54]	validation_0-auc:0.70628	validation_1-auc:0.68227
# [55]	validation_0-auc:0.70656	validation_1-auc:0.68249
# [56]	validation_0-auc:0.70674	validation_1-auc:0.68275
# [57]	validation_0-auc:0.70703	validation_1-auc:0.68284
# [58]	validation_0-auc:0.70734	validation_1-auc:0.68318
# [59]	validation_0-auc:0.70746	validation_1-auc:0.68324
# [60]	validation_0-auc:0.70795	validation_1-auc:0.68372
# [61]	validation_0-auc:0.70814	validation_1-auc:0.68377
# [62]	validation_0-auc:0.70893	validation_1-auc:0.68462
# [63]	validation_0-auc:0.71010	validation_1-auc:0.68503
# [64]	validation_0-auc:0.71021	validation_1-auc:0.68518
# [65]	validation_0-auc:0.71032	validation_1-auc:0.68520
# [66]	validation_0-auc:0.71114	validation_1-auc:0.68593
# [67]	validation_0-auc:0.71181	validation_1-auc:0.68633
# [68]	validation_0-auc:0.71198	validation_1-auc:0.68646
# [69]	validation_0-auc:0.71257	validation_1-auc:0.68684
# [70]	validation_0-auc:0.71279	validation_1-auc:0.68707
# [71]	validation_0-auc:0.71299	validation_1-auc:0.68715
# [72]	validation_0-auc:0.71330	validation_1-auc:0.68729
# [73]	validation_0-auc:0.71352	validation_1-auc:0.68746
# [74]	validation_0-auc:0.71433	validation_1-auc:0.68819
# [75]	validation_0-auc:0.71469	validation_1-auc:0.68855
# [76]	validation_0-auc:0.71487	validation_1-auc:0.68857
# [77]	validation_0-auc:0.71515	validation_1-auc:0.68874
# [78]	validation_0-auc:0.71561	validation_1-auc:0.68904
# [79]	validation_0-auc:0.71590	validation_1-auc:0.68922
# [80]	validation_0-auc:0.71632	validation_1-auc:0.68941
# [81]	validation_0-auc:0.71658	validation_1-auc:0.68951
# [82]	validation_0-auc:0.71684	validation_1-auc:0.68975
# [83]	validation_0-auc:0.71707	validation_1-auc:0.68974
# [84]	validation_0-auc:0.71762	validation_1-auc:0.69006
# [85]	validation_0-auc:0.71769	validation_1-auc:0.69013
# [86]	validation_0-auc:0.71779	validation_1-auc:0.69020
# [87]	validation_0-auc:0.71789	validation_1-auc:0.69024
# [88]	validation_0-auc:0.71817	validation_1-auc:0.69041
# [89]	validation_0-auc:0.71875	validation_1-auc:0.69051
# [90]	validation_0-auc:0.71913	validation_1-auc:0.69077
# [91]	validation_0-auc:0.71919	validation_1-auc:0.69083
# [92]	validation_0-auc:0.71960	validation_1-auc:0.69110
# [93]	validation_0-auc:0.72003	validation_1-auc:0.69154
# [94]	validation_0-auc:0.72053	validation_1-auc:0.69176
# [95]	validation_0-auc:0.72080	validation_1-auc:0.69190
# [96]	validation_0-auc:0.72142	validation_1-auc:0.69230
# [97]	validation_0-auc:0.72150	validation_1-auc:0.69237
# [98]	validation_0-auc:0.72195	validation_1-auc:0.69257
# [99]	validation_0-auc:0.72208	validation_1-auc:0.69259
# [100]	validation_0-auc:0.72224	validation_1-auc:0.69279
# [101]	validation_0-auc:0.72264	validation_1-auc:0.69300
# [102]	validation_0-auc:0.72308	validation_1-auc:0.69332
# [103]	validation_0-auc:0.72350	validation_1-auc:0.69349
# [104]	validation_0-auc:0.72384	validation_1-auc:0.69365
# [105]	validation_0-auc:0.72399	validation_1-auc:0.69380
# [106]	validation_0-auc:0.72457	validation_1-auc:0.69408
# [107]	validation_0-auc:0.72471	validation_1-auc:0.69422
# [108]	validation_0-auc:0.72483	validation_1-auc:0.69433
# [109]	validation_0-auc:0.72508	validation_1-auc:0.69435
# [110]	validation_0-auc:0.72540	validation_1-auc:0.69450
# [111]	validation_0-auc:0.72582	validation_1-auc:0.69476
# [112]	validation_0-auc:0.72604	validation_1-auc:0.69480
# [113]	validation_0-auc:0.72639	validation_1-auc:0.69490
# [114]	validation_0-auc:0.72654	validation_1-auc:0.69491
# [115]	validation_0-auc:0.72678	validation_1-auc:0.69513
# [116]	validation_0-auc:0.72692	validation_1-auc:0.69517
# [117]	validation_0-auc:0.72712	validation_1-auc:0.69535
# [118]	validation_0-auc:0.72717	validation_1-auc:0.69539
# [119]	validation_0-auc:0.72728	validation_1-auc:0.69543
# [120]	validation_0-auc:0.72792	validation_1-auc:0.69575
# [121]	validation_0-auc:0.72832	validation_1-auc:0.69609
# [122]	validation_0-auc:0.72857	validation_1-auc:0.69623
# [123]	validation_0-auc:0.72874	validation_1-auc:0.69633
# [124]	validation_0-auc:0.72889	validation_1-auc:0.69642
# [125]	validation_0-auc:0.72899	validation_1-auc:0.69649
# [126]	validation_0-auc:0.72923	validation_1-auc:0.69649
# [127]	validation_0-auc:0.72932	validation_1-auc:0.69652
# [128]	validation_0-auc:0.72949	validation_1-auc:0.69661
# [129]	validation_0-auc:0.73000	validation_1-auc:0.69699
# [130]	validation_0-auc:0.73044	validation_1-auc:0.69734
# [131]	validation_0-auc:0.73089	validation_1-auc:0.69752
# [132]	validation_0-auc:0.73128	validation_1-auc:0.69786
# [133]	validation_0-auc:0.73167	validation_1-auc:0.69796
# [134]	validation_0-auc:0.73191	validation_1-auc:0.69806
# [135]	validation_0-auc:0.73194	validation_1-auc:0.69811
# [136]	validation_0-auc:0.73216	validation_1-auc:0.69822
# [137]	validation_0-auc:0.73221	validation_1-auc:0.69825
# [138]	validation_0-auc:0.73236	validation_1-auc:0.69829
# [139]	validation_0-auc:0.73283	validation_1-auc:0.69841
# [140]	validation_0-auc:0.73314	validation_1-auc:0.69856
# [141]	validation_0-auc:0.73332	validation_1-auc:0.69856
# [142]	validation_0-auc:0.73361	validation_1-auc:0.69881
# [143]	validation_0-auc:0.73369	validation_1-auc:0.69878
# [144]	validation_0-auc:0.73386	validation_1-auc:0.69890
# [145]	validation_0-auc:0.73427	validation_1-auc:0.69910
# [146]	validation_0-auc:0.73436	validation_1-auc:0.69912
# [147]	validation_0-auc:0.73442	validation_1-auc:0.69913
# [148]	validation_0-auc:0.73462	validation_1-auc:0.69931
# [149]	validation_0-auc:0.73464	validation_1-auc:0.69930
# [150]	validation_0-auc:0.73494	validation_1-auc:0.69934
# [151]	validation_0-auc:0.73531	validation_1-auc:0.69956
# [152]	validation_0-auc:0.73555	validation_1-auc:0.69970
# [153]	validation_0-auc:0.73585	validation_1-auc:0.69977
# [154]	validation_0-auc:0.73625	validation_1-auc:0.69999
# [155]	validation_0-auc:0.73674	validation_1-auc:0.70025
# [156]	validation_0-auc:0.73699	validation_1-auc:0.70038
# [157]	validation_0-auc:0.73706	validation_1-auc:0.70034
# [158]	validation_0-auc:0.73761	validation_1-auc:0.70051
# [159]	validation_0-auc:0.73769	validation_1-auc:0.70059
# [160]	validation_0-auc:0.73789	validation_1-auc:0.70075
# [161]	validation_0-auc:0.73831	validation_1-auc:0.70099
# [162]	validation_0-auc:0.73861	validation_1-auc:0.70118
# [163]	validation_0-auc:0.73878	validation_1-auc:0.70132
# [164]	validation_0-auc:0.73892	validation_1-auc:0.70142
# [165]	validation_0-auc:0.73935	validation_1-auc:0.70176
# [166]	validation_0-auc:0.73944	validation_1-auc:0.70179
# [167]	validation_0-auc:0.73959	validation_1-auc:0.70185
# [168]	validation_0-auc:0.73973	validation_1-auc:0.70202
# [169]	validation_0-auc:0.73997	validation_1-auc:0.70219
# [170]	validation_0-auc:0.74033	validation_1-auc:0.70249
# [171]	validation_0-auc:0.74069	validation_1-auc:0.70265
# [172]	validation_0-auc:0.74080	validation_1-auc:0.70267
# [173]	validation_0-auc:0.74119	validation_1-auc:0.70288
# [174]	validation_0-auc:0.74177	validation_1-auc:0.70305
# [175]	validation_0-auc:0.74203	validation_1-auc:0.70323
# [176]	validation_0-auc:0.74221	validation_1-auc:0.70325
# [177]	validation_0-auc:0.74260	validation_1-auc:0.70347
# [178]	validation_0-auc:0.74290	validation_1-auc:0.70356
# [179]	validation_0-auc:0.74318	validation_1-auc:0.70376
# [180]	validation_0-auc:0.74355	validation_1-auc:0.70395
# [181]	validation_0-auc:0.74397	validation_1-auc:0.70396
# [182]	validation_0-auc:0.74416	validation_1-auc:0.70403
# [183]	validation_0-auc:0.74450	validation_1-auc:0.70409
# [184]	validation_0-auc:0.74468	validation_1-auc:0.70412
# [185]	validation_0-auc:0.74499	validation_1-auc:0.70429
# [186]	validation_0-auc:0.74518	validation_1-auc:0.70435
# [187]	validation_0-auc:0.74520	validation_1-auc:0.70443
# [188]	validation_0-auc:0.74559	validation_1-auc:0.70466
# [189]	validation_0-auc:0.74585	validation_1-auc:0.70479
# [190]	validation_0-auc:0.74591	validation_1-auc:0.70480
# [191]	validation_0-auc:0.74608	validation_1-auc:0.70488
# [192]	validation_0-auc:0.74636	validation_1-auc:0.70502
# [193]	validation_0-auc:0.74660	validation_1-auc:0.70516
# [194]	validation_0-auc:0.74685	validation_1-auc:0.70530
# [195]	validation_0-auc:0.74717	validation_1-auc:0.70541
# [196]	validation_0-auc:0.74730	validation_1-auc:0.70542
# [197]	validation_0-auc:0.74759	validation_1-auc:0.70567
# [198]	validation_0-auc:0.74784	validation_1-auc:0.70594
# [199]	validation_0-auc:0.74801	validation_1-auc:0.70609
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.75, eta=0.1,
#               eval_metric='auc', gamma=10.3, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.100000001,
#               max_delta_step=0, max_depth=5, min_child_weight=300, missing=nan,
#               monotone_constraints='()', n_estimators=200, n_jobs=56,
#               num_parallel_tree=1, random_state=0, reg_alpha=1.2,
#               reg_lambda=8.16, scale_pos_weight=4.5, subsample=0.8,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# ## 二、Recycle挑选特征，强化模型

# %% [markdown]
# 在已确定近似最佳参数的情况下，本节使用全部训练集的数据。本节使用了**recycle技巧**，先将训练集全部放到最佳模型中训练，由第一次训练后的模型获得所有特征的重要性(feature_importance)，然后挑选重要性最高的50个特征(原来共有72维特征, 选50维是经过查看重要性大小和反复多次实验确定的)，根据这个**循环反馈**，再次使用这50维特征再次建立模型，此模型除subsample由0.8增大到0.9外其余参数完全一致。

# %%
# 使用全部训练数据，不再拆分train、validation
train_label = split_train_data_feature['label']
train_data = split_train_data_feature.drop(columns=['user_id','merchant_id','label'],axis=1)

# %%
# 第一次建模训练，获取最佳参数下各个特征的重要性，为下一步挑选做准备
xgb_predict_model = xgb.XGBClassifier(
    eta = 0.1,
    n_estimators = 200,
    max_depth = 5, # default=6
    min_child_weight = 300, # default=1
    gamma = 10.3, # default=0
    subsample = 0.8, # default=1
    colsample_bytree = 0.75, # default=1
    reg_alpha = 1.2,
    reg_lambda = 8.16,
    eval_metric = 'auc',
    scale_pos_weight = 4.5
)
xgb_predict_model.fit(
    train_data, 
    train_label, 
    eval_set=[(train_data, train_label)],
    verbose = True,
    early_stopping_rounds = 40,
)
# Out:
# [0]	validation_0-auc:0.63937
# [1]	validation_0-auc:0.65001
# [2]	validation_0-auc:0.65760
# [3]	validation_0-auc:0.66165
# [4]	validation_0-auc:0.66445
# [5]	validation_0-auc:0.66515
# [6]	validation_0-auc:0.66552
# [7]	validation_0-auc:0.66717
# [8]	validation_0-auc:0.66885
# [9]	validation_0-auc:0.67083
# [10]	validation_0-auc:0.67260
# [11]	validation_0-auc:0.67346
# [12]	validation_0-auc:0.67531
# [13]	validation_0-auc:0.67693
# [14]	validation_0-auc:0.67784
# [15]	validation_0-auc:0.67891
# [16]	validation_0-auc:0.68001
# [17]	validation_0-auc:0.68111
# [18]	validation_0-auc:0.68208
# [19]	validation_0-auc:0.68317
# [20]	validation_0-auc:0.68390
# [21]	validation_0-auc:0.68465
# [22]	validation_0-auc:0.68588
# [23]	validation_0-auc:0.68685
# [24]	validation_0-auc:0.68741
# [25]	validation_0-auc:0.68801
# [26]	validation_0-auc:0.68887
# [27]	validation_0-auc:0.68972
# [28]	validation_0-auc:0.69040
# [29]	validation_0-auc:0.69161
# [30]	validation_0-auc:0.69221
# [31]	validation_0-auc:0.69343
# [32]	validation_0-auc:0.69427
# [33]	validation_0-auc:0.69471
# [34]	validation_0-auc:0.69589
# [35]	validation_0-auc:0.69629
# [36]	validation_0-auc:0.69706
# [37]	validation_0-auc:0.69781
# [38]	validation_0-auc:0.69829
# [39]	validation_0-auc:0.69904
# [40]	validation_0-auc:0.69947
# [41]	validation_0-auc:0.70027
# [42]	validation_0-auc:0.70086
# [43]	validation_0-auc:0.70117
# [44]	validation_0-auc:0.70144
# [45]	validation_0-auc:0.70211
# [46]	validation_0-auc:0.70218
# [47]	validation_0-auc:0.70295
# [48]	validation_0-auc:0.70341
# [49]	validation_0-auc:0.70408
# [50]	validation_0-auc:0.70451
# [51]	validation_0-auc:0.70524
# [52]	validation_0-auc:0.70562
# [53]	validation_0-auc:0.70595
# [54]	validation_0-auc:0.70652
# [55]	validation_0-auc:0.70676
# [56]	validation_0-auc:0.70736
# [57]	validation_0-auc:0.70761
# [58]	validation_0-auc:0.70793
# [59]	validation_0-auc:0.70812
# [60]	validation_0-auc:0.70836
# [61]	validation_0-auc:0.70903
# [62]	validation_0-auc:0.70964
# [63]	validation_0-auc:0.71013
# [64]	validation_0-auc:0.71086
# [65]	validation_0-auc:0.71100
# [66]	validation_0-auc:0.71124
# [67]	validation_0-auc:0.71137
# [68]	validation_0-auc:0.71174
# [69]	validation_0-auc:0.71197
# [70]	validation_0-auc:0.71236
# [71]	validation_0-auc:0.71277
# [72]	validation_0-auc:0.71339
# [73]	validation_0-auc:0.71367
# [74]	validation_0-auc:0.71414
# [75]	validation_0-auc:0.71471
# [76]	validation_0-auc:0.71512
# [77]	validation_0-auc:0.71557
# [78]	validation_0-auc:0.71602
# [79]	validation_0-auc:0.71642
# [80]	validation_0-auc:0.71663
# [81]	validation_0-auc:0.71705
# [82]	validation_0-auc:0.71760
# [83]	validation_0-auc:0.71799
# [84]	validation_0-auc:0.71808
# [85]	validation_0-auc:0.71821
# [86]	validation_0-auc:0.71858
# [87]	validation_0-auc:0.71909
# [88]	validation_0-auc:0.71952
# [89]	validation_0-auc:0.71973
# [90]	validation_0-auc:0.71995
# [91]	validation_0-auc:0.72036
# [92]	validation_0-auc:0.72057
# [93]	validation_0-auc:0.72066
# [94]	validation_0-auc:0.72087
# [95]	validation_0-auc:0.72111
# [96]	validation_0-auc:0.72148
# [97]	validation_0-auc:0.72164
# [98]	validation_0-auc:0.72189
# [99]	validation_0-auc:0.72204
# [100]	validation_0-auc:0.72224
# [101]	validation_0-auc:0.72259
# [102]	validation_0-auc:0.72269
# [103]	validation_0-auc:0.72315
# [104]	validation_0-auc:0.72337
# [105]	validation_0-auc:0.72372
# [106]	validation_0-auc:0.72401
# [107]	validation_0-auc:0.72423
# [108]	validation_0-auc:0.72450
# [109]	validation_0-auc:0.72481
# [110]	validation_0-auc:0.72508
# [111]	validation_0-auc:0.72548
# [112]	validation_0-auc:0.72584
# [113]	validation_0-auc:0.72620
# [114]	validation_0-auc:0.72648
# [115]	validation_0-auc:0.72661
# [116]	validation_0-auc:0.72667
# [117]	validation_0-auc:0.72715
# [118]	validation_0-auc:0.72729
# [119]	validation_0-auc:0.72762
# [120]	validation_0-auc:0.72797
# [121]	validation_0-auc:0.72850
# [122]	validation_0-auc:0.72894
# [123]	validation_0-auc:0.72913
# [124]	validation_0-auc:0.72937
# [125]	validation_0-auc:0.72961
# [126]	validation_0-auc:0.72999
# [127]	validation_0-auc:0.72999
# [128]	validation_0-auc:0.73012
# [129]	validation_0-auc:0.73047
# [130]	validation_0-auc:0.73081
# [131]	validation_0-auc:0.73099
# [132]	validation_0-auc:0.73141
# [133]	validation_0-auc:0.73188
# [134]	validation_0-auc:0.73222
# [135]	validation_0-auc:0.73227
# [136]	validation_0-auc:0.73236
# [137]	validation_0-auc:0.73247
# [138]	validation_0-auc:0.73278
# [139]	validation_0-auc:0.73319
# [140]	validation_0-auc:0.73352
# [141]	validation_0-auc:0.73381
# [142]	validation_0-auc:0.73395
# [143]	validation_0-auc:0.73440
# [144]	validation_0-auc:0.73472
# [145]	validation_0-auc:0.73501
# [146]	validation_0-auc:0.73515
# [147]	validation_0-auc:0.73547
# [148]	validation_0-auc:0.73571
# [149]	validation_0-auc:0.73585
# [150]	validation_0-auc:0.73595
# [151]	validation_0-auc:0.73608
# [152]	validation_0-auc:0.73625
# [153]	validation_0-auc:0.73660
# [154]	validation_0-auc:0.73680
# [155]	validation_0-auc:0.73694
# [156]	validation_0-auc:0.73720
# [157]	validation_0-auc:0.73746
# [158]	validation_0-auc:0.73764
# [159]	validation_0-auc:0.73778
# [160]	validation_0-auc:0.73801
# [161]	validation_0-auc:0.73819
# [162]	validation_0-auc:0.73828
# [163]	validation_0-auc:0.73864
# [164]	validation_0-auc:0.73881
# [165]	validation_0-auc:0.73918
# [166]	validation_0-auc:0.73938
# [167]	validation_0-auc:0.73968
# [168]	validation_0-auc:0.73976
# [169]	validation_0-auc:0.73997
# [170]	validation_0-auc:0.74030
# [171]	validation_0-auc:0.74055
# [172]	validation_0-auc:0.74065
# [173]	validation_0-auc:0.74086
# [174]	validation_0-auc:0.74096
# [175]	validation_0-auc:0.74122
# [176]	validation_0-auc:0.74130
# [177]	validation_0-auc:0.74151
# [178]	validation_0-auc:0.74162
# [179]	validation_0-auc:0.74205
# [180]	validation_0-auc:0.74213
# [181]	validation_0-auc:0.74243
# [182]	validation_0-auc:0.74265
# [183]	validation_0-auc:0.74295
# [184]	validation_0-auc:0.74302
# [185]	validation_0-auc:0.74305
# [186]	validation_0-auc:0.74350
# [187]	validation_0-auc:0.74356
# [188]	validation_0-auc:0.74367
# [189]	validation_0-auc:0.74392
# [190]	validation_0-auc:0.74397
# [191]	validation_0-auc:0.74409
# [192]	validation_0-auc:0.74442
# [193]	validation_0-auc:0.74464
# [194]	validation_0-auc:0.74507
# [195]	validation_0-auc:0.74527
# [196]	validation_0-auc:0.74550
# [197]	validation_0-auc:0.74569
# [198]	validation_0-auc:0.74593
# [199]	validation_0-auc:0.74604
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.75, eta=0.1,
#               eval_metric='auc', gamma=10.3, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.100000001,
#               max_delta_step=0, max_depth=5, min_child_weight=300, missing=nan,
#               monotone_constraints='()', n_estimators=200, n_jobs=56,
#               num_parallel_tree=1, random_state=0, reg_alpha=1.2,
#               reg_lambda=8.16, scale_pos_weight=4.5, subsample=0.8,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %%
# 获取特征重要性矩阵
importance_df = pd.DataFrame(split_train_data_feature.columns.drop(['user_id', 'merchant_id', 'label']),
                             columns=['feature'])
importance_df['importance'] = xgb_predict_model.feature_importances_
importance_df.sort_values(by='importance', ascending=False, inplace=True)
# importance_df.to_csv('feature_importance.csv', index=False)
high_imp_f = importance_df['feature'][:50] # top 50

# %% [markdown]
# Note: 第二次建模将subsample(训练采样率)由0.8增大到0.9，大量对比实验表明这样可以提升拟合效果。**筛掉低重要性特征并增大训练采样率共同提升效果的可解释性：筛掉低重要性特征可以消除其中带有的噪声信号，如此小幅增大训练采样率并不会使模型过拟合，反而会过滤掉噪声并收敛更快。**

# %% [markdown]
# Note: 通过recyle技巧，算法提交结果有0.6862提升到0.6876，由排行榜101名提升到91名，提升明显。

# %%
# 第二次建模训练，使用高重要性特征，生成本算法最终模型

# 挑选高重要性特征
train_data = split_train_data_feature.drop(columns=['user_id','merchant_id','label'],axis=1)[high_imp_f]

xgb_predict_model = xgb.XGBClassifier(
    eta = 0.1,
    n_estimators = 200,
    max_depth = 5,
    min_child_weight = 300,
    gamma = 10.3,
    subsample = 0.9, # 滤除噪声后，训练采样率由0.8增大到0.9
    colsample_bytree = 0.75,
    reg_alpha = 1.2,
    reg_lambda = 8.16,
    eval_metric = 'auc',
    scale_pos_weight = 4.5
)
xgb_predict_model.fit(
    train_data, 
    train_label, 
    eval_set=[(train_data, train_label)],
    verbose = True,
    early_stopping_rounds = 40,
)
# Out:
# [0]	validation_0-auc:0.64300
# [1]	validation_0-auc:0.65035
# [2]	validation_0-auc:0.65429
# [3]	validation_0-auc:0.65592
# [4]	validation_0-auc:0.65710
# [5]	validation_0-auc:0.66196
# [6]	validation_0-auc:0.66278
# [7]	validation_0-auc:0.66580
# [8]	validation_0-auc:0.66797
# [9]	validation_0-auc:0.66954
# [10]	validation_0-auc:0.67127
# [11]	validation_0-auc:0.67237
# [12]	validation_0-auc:0.67321
# [13]	validation_0-auc:0.67468
# [14]	validation_0-auc:0.67667
# [15]	validation_0-auc:0.67833
# [16]	validation_0-auc:0.67944
# [17]	validation_0-auc:0.68039
# [18]	validation_0-auc:0.68138
# [19]	validation_0-auc:0.68211
# [20]	validation_0-auc:0.68321
# [21]	validation_0-auc:0.68368
# [22]	validation_0-auc:0.68446
# [23]	validation_0-auc:0.68507
# [24]	validation_0-auc:0.68629
# [25]	validation_0-auc:0.68720
# [26]	validation_0-auc:0.68798
# [27]	validation_0-auc:0.68866
# [28]	validation_0-auc:0.68961
# [29]	validation_0-auc:0.69053
# [30]	validation_0-auc:0.69163
# [31]	validation_0-auc:0.69254
# [32]	validation_0-auc:0.69327
# [33]	validation_0-auc:0.69397
# [34]	validation_0-auc:0.69442
# [35]	validation_0-auc:0.69536
# [36]	validation_0-auc:0.69585
# [37]	validation_0-auc:0.69640
# [38]	validation_0-auc:0.69781
# [39]	validation_0-auc:0.69837
# [40]	validation_0-auc:0.69896
# [41]	validation_0-auc:0.69968
# [42]	validation_0-auc:0.69999
# [43]	validation_0-auc:0.70057
# [44]	validation_0-auc:0.70137
# [45]	validation_0-auc:0.70182
# [46]	validation_0-auc:0.70214
# [47]	validation_0-auc:0.70246
# [48]	validation_0-auc:0.70271
# [49]	validation_0-auc:0.70328
# [50]	validation_0-auc:0.70389
# [51]	validation_0-auc:0.70481
# [52]	validation_0-auc:0.70539
# [53]	validation_0-auc:0.70594
# [54]	validation_0-auc:0.70612
# [55]	validation_0-auc:0.70675
# [56]	validation_0-auc:0.70745
# [57]	validation_0-auc:0.70751
# [58]	validation_0-auc:0.70766
# [59]	validation_0-auc:0.70790
# [60]	validation_0-auc:0.70850
# [61]	validation_0-auc:0.70884
# [62]	validation_0-auc:0.70938
# [63]	validation_0-auc:0.70960
# [64]	validation_0-auc:0.71020
# [65]	validation_0-auc:0.71051
# [66]	validation_0-auc:0.71070
# [67]	validation_0-auc:0.71130
# [68]	validation_0-auc:0.71149
# [69]	validation_0-auc:0.71212
# [70]	validation_0-auc:0.71247
# [71]	validation_0-auc:0.71277
# [72]	validation_0-auc:0.71334
# [73]	validation_0-auc:0.71358
# [74]	validation_0-auc:0.71376
# [75]	validation_0-auc:0.71396
# [76]	validation_0-auc:0.71425
# [77]	validation_0-auc:0.71452
# [78]	validation_0-auc:0.71468
# [79]	validation_0-auc:0.71518
# [80]	validation_0-auc:0.71533
# [81]	validation_0-auc:0.71573
# [82]	validation_0-auc:0.71605
# [83]	validation_0-auc:0.71642
# [84]	validation_0-auc:0.71649
# [85]	validation_0-auc:0.71687
# [86]	validation_0-auc:0.71697
# [87]	validation_0-auc:0.71703
# [88]	validation_0-auc:0.71737
# [89]	validation_0-auc:0.71746
# [90]	validation_0-auc:0.71764
# [91]	validation_0-auc:0.71799
# [92]	validation_0-auc:0.71834
# [93]	validation_0-auc:0.71847
# [94]	validation_0-auc:0.71857
# [95]	validation_0-auc:0.71904
# [96]	validation_0-auc:0.71937
# [97]	validation_0-auc:0.71959
# [98]	validation_0-auc:0.72017
# [99]	validation_0-auc:0.72073
# [100]	validation_0-auc:0.72084
# [101]	validation_0-auc:0.72099
# [102]	validation_0-auc:0.72118
# [103]	validation_0-auc:0.72166
# [104]	validation_0-auc:0.72176
# [105]	validation_0-auc:0.72221
# [106]	validation_0-auc:0.72237
# [107]	validation_0-auc:0.72248
# [108]	validation_0-auc:0.72277
# [109]	validation_0-auc:0.72285
# [110]	validation_0-auc:0.72309
# [111]	validation_0-auc:0.72345
# [112]	validation_0-auc:0.72370
# [113]	validation_0-auc:0.72385
# [114]	validation_0-auc:0.72415
# [115]	validation_0-auc:0.72423
# [116]	validation_0-auc:0.72450
# [117]	validation_0-auc:0.72472
# [118]	validation_0-auc:0.72492
# [119]	validation_0-auc:0.72541
# [120]	validation_0-auc:0.72556
# [121]	validation_0-auc:0.72564
# [122]	validation_0-auc:0.72588
# [123]	validation_0-auc:0.72598
# [124]	validation_0-auc:0.72610
# [125]	validation_0-auc:0.72639
# [126]	validation_0-auc:0.72664
# [127]	validation_0-auc:0.72669
# [128]	validation_0-auc:0.72699
# [129]	validation_0-auc:0.72732
# [130]	validation_0-auc:0.72781
# [131]	validation_0-auc:0.72793
# [132]	validation_0-auc:0.72837
# [133]	validation_0-auc:0.72870
# [134]	validation_0-auc:0.72888
# [135]	validation_0-auc:0.72896
# [136]	validation_0-auc:0.72901
# [137]	validation_0-auc:0.72929
# [138]	validation_0-auc:0.72946
# [139]	validation_0-auc:0.72945
# [140]	validation_0-auc:0.72952
# [141]	validation_0-auc:0.72959
# [142]	validation_0-auc:0.73003
# [143]	validation_0-auc:0.73043
# [144]	validation_0-auc:0.73053
# [145]	validation_0-auc:0.73079
# [146]	validation_0-auc:0.73101
# [147]	validation_0-auc:0.73117
# [148]	validation_0-auc:0.73150
# [149]	validation_0-auc:0.73167
# [150]	validation_0-auc:0.73181
# [151]	validation_0-auc:0.73181
# [152]	validation_0-auc:0.73208
# [153]	validation_0-auc:0.73243
# [154]	validation_0-auc:0.73273
# [155]	validation_0-auc:0.73312
# [156]	validation_0-auc:0.73341
# [157]	validation_0-auc:0.73353
# [158]	validation_0-auc:0.73361
# [159]	validation_0-auc:0.73367
# [160]	validation_0-auc:0.73375
# [161]	validation_0-auc:0.73413
# [162]	validation_0-auc:0.73420
# [163]	validation_0-auc:0.73453
# [164]	validation_0-auc:0.73473
# [165]	validation_0-auc:0.73501
# [166]	validation_0-auc:0.73537
# [167]	validation_0-auc:0.73539
# [168]	validation_0-auc:0.73558
# [169]	validation_0-auc:0.73575
# [170]	validation_0-auc:0.73579
# [171]	validation_0-auc:0.73590
# [172]	validation_0-auc:0.73606
# [173]	validation_0-auc:0.73625
# [174]	validation_0-auc:0.73632
# [175]	validation_0-auc:0.73668
# [176]	validation_0-auc:0.73700
# [177]	validation_0-auc:0.73712
# [178]	validation_0-auc:0.73716
# [179]	validation_0-auc:0.73734
# [180]	validation_0-auc:0.73757
# [181]	validation_0-auc:0.73759
# [182]	validation_0-auc:0.73792
# [183]	validation_0-auc:0.73815
# [184]	validation_0-auc:0.73819
# [185]	validation_0-auc:0.73822
# [186]	validation_0-auc:0.73844
# [187]	validation_0-auc:0.73867
# [188]	validation_0-auc:0.73890
# [189]	validation_0-auc:0.73897
# [190]	validation_0-auc:0.73910
# [191]	validation_0-auc:0.73927
# [192]	validation_0-auc:0.73953
# [193]	validation_0-auc:0.73987
# [194]	validation_0-auc:0.74008
# [195]	validation_0-auc:0.74027
# [196]	validation_0-auc:0.74029
# [197]	validation_0-auc:0.74052
# [198]	validation_0-auc:0.74064
# [199]	validation_0-auc:0.74078
# XGBClassifier(base_score=0.5, booster='gbtree', colsample_bylevel=1,
#               colsample_bynode=1, colsample_bytree=0.75, eta=0.1,
#               eval_metric='auc', gamma=10.3, gpu_id=-1, importance_type='gain',
#               interaction_constraints='', learning_rate=0.100000001,
#               max_delta_step=0, max_depth=5, min_child_weight=300, missing=nan,
#               monotone_constraints='()', n_estimators=200, n_jobs=56,
#               num_parallel_tree=1, random_state=0, reg_alpha=1.2,
#               reg_lambda=8.16, scale_pos_weight=4.5, subsample=0.9,
#               tree_method='exact', validate_parameters=1, verbosity=None)

# %% [markdown]
# ## 三、预测，保存

# %%
# 放到模型中进行预测，生成结果
# 预测
test_predict_prob = xgb_predict_model.predict_proba(split_test_data_feature[high_imp_f])
# 整合结合
submission_df = split_test_data.copy().drop(columns=['prob'])
submission_df['xgb_boost_prob'] = test_predict_prob[:,1]
submission_df.rename(columns={'xgb_boost_prob':'prob'},inplace=True)
submission_df.head(10)
# Out:
#    user_id  merchant_id      prob
# 0   163968         4605  0.357426
# 1   360576         1581  0.551531
# 2    98688         1964  0.382418
# 3    98688         3645  0.220104
# 4   295296         3361  0.340570
# 5    33408           98  0.156705
# 6   230016         1742  0.457133
# 7   164736          598  0.281444
# 8   164736         1963  0.097014
# 9   164736         2634  0.325702

# %%
# 观察预测结果统计分布，给效果一个instinct
submission_df['prob'].min(), submission_df['prob'].max(), submission_df['prob'].mean(), submission_df['prob'].sum(), (submission_df['prob']>=0.5).sum()
# Out:
# (0.05096617341041565, 0.9223620295524597, 0.3290819823741913, 86047.23, 32241)

# %%
# 写入本地文件保存
submission_df.to_csv(path_or_buf='./repurchase_submission.csv', index=False)
